# %% [markdown]
# # Processador de planilha
# - Recebe uma planilha obtida de https://dados.gov.br/dados/conjuntos-dados/previsao-climatica-do-censipam
# - Lê os registros
# - Realiza composições
# - Faz inserções no BD

# %%
import pandas as pd
df = pd.read_csv('..\\documentos\\previsaoTempoDadoAbertoOut2022_gerado_01112022_100000.csv')

# %%
import mysql.connector
#python -m pip install mysql-connector-python
mydb = mysql.connector.connect(
  host="localhost",
  user="yourusername",
  password="yourpassword",
  database="mydatabase"
)
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# c:\users\ricar\appdata\local\programs\python\python37\lib\site-packages\mysql\connector\network.py in open_connection(self)
#     566             self.sock.settimeout(self._connection_timeout)
# --> 567             self.sock.connect(sockaddr)
#     568         except IOError as err:
#
# ConnectionRefusedError: [WinError 10061] Nenhuma conexão pôde ser feita porque a máquina de destino as recusou ativamente
#
# The above exception was the direct cause of the following exception:
#
# InterfaceError                            Traceback (most recent call last)
# <ipython-input-5-f92d7b4cd46c> in <module>
#       5   user="yourusername",
#       6   password="yourpassword",
# ----> 7   database="mydatabase"
#       8 )
#
# c:\users\ricar\appdata\local\programs\python\python37\lib\site-packages\mysql\connector\pooling.py in connect(*args, **kwargs)
#     285     if CMySQLConnection and not use_pure:
#     286         return CMySQLConnection(*args, **kwargs)
# --> 287     return MySQLConnection(*args, **kwargs)
#     288
#     289
#
# c:\users\ricar\appdata\local\programs\python\python37\lib\site-packages\mysql\connector\connection.py in __init__(self, **kwargs)
#     135         if kwargs:
#     136             try:
# --> 137                 self.connect(**kwargs)
#     138             except Exception:
#     139                 # Tidy-up underlying socket on failure
#
# c:\users\ricar\appdata\local\programs\python\python37\lib\site-packages\mysql\connector\abstracts.py in connect(self, **kwargs)
#    1106
#    1107         self.disconnect()
# -> 1108         self._open_connection()
#    1109         # Server does not allow to run any other statement different from ALTER
#    1110         # when user's password has been expired.
#
# c:\users\ricar\appdata\local\programs\python\python37\lib\site-packages\mysql\connector\connection.py in _open_connection(self)
#     531         self._socket = self._get_connection()
#     532         try:
# --> 533             self._socket.open_connection()
#     534             self._do_handshake()
#     535             self._do_auth(
#
# c:\users\ricar\appdata\local\programs\python\python37\lib\site-packages\mysql\connector\network.py in open_connection(self)
#     574                     _strioerror(err),
#     575                 ),
# --> 576             ) from err
#     577         except Exception as err:
#     578             raise OperationalError(str(err)) from err
#
# InterfaceError: 2003: Can't connect to MySQL server on 'localhost:3306' (10061 Nenhuma conexão pôde ser feita porque a máquina de destino as recusou ativamente)

# %%
df
# Out:
#             Data           Cidade  \
# 0     04/10/2022  Abaetetuba - PA
# 1     05/10/2022  Abaetetuba - PA
# 2     06/10/2022  Abaetetuba - PA
# 3     07/10/2022  Abaetetuba - PA
# 4     08/10/2022  Abaetetuba - PA
# ...          ...              ...
# 8841  27/10/2022    Xinguara - PA
# 8842  28/10/2022    Xinguara - PA
# 8843  29/10/2022    Xinguara - PA
# 8844  30/10/2022    Xinguara - PA
# 8845  31/10/2022    Xinguara - PA
#
#                              Condicao_do_Tempo_Prevista Temperatura_Tendencia  \
# 0     Claro a nublado com pancadas de chuva isoladas...               Estavel
# 1     Claro a nublado com pancadas de chuva isoladas...               Estavel
# 2     Claro a nublado com pancadas de chuva isoladas...               Estavel
# 3     Poucas nuvens a nublado com possibilidade de c...               Estavel
# 4     Poucas nuvens a nublado com pancadas de chuva ...               Estavel
# ...                                                 ...                   ...
# 8841  Parcialmente nublado a nublado com chuva e tro...               Estavel
# 8842  Nublado a parcialmente nublado com chuva e tro...               Estavel
# 8843  Parcialmente nublado a nublado com pancadas de...               Estavel
# 8844  Parcialmente nublado a nublado com pancadas de...               Estavel
# 8845  Nublado a parcialmente nublado com chuva e tro...               Estavel
#
#       Temperatura_Minima  Temperatura_Maxima  Vento_Velocidade_Minima  \
# 0                     24                  34                       50
# 1                     24                  34                       50
# 2                     24                  34                       50
# 3                     24                  34                       50
# 4                     24                  34                       50
# ...                  ...                 ...                      ...
# 8841                  23                  32                       60
# 8842                  23                  31                       65
# 8843                  23                  32                       60
# 8844                  23                  32                       60
# 8845                  23                  31                       60
#
#       Vento_Velocidade_Maxima Vento_Direcao Vento_Intensidade
# 0                          95        SE - E  Fracos/Moderados
# 1                          95        SE - E  Fracos/Moderados
# 2                          95        SE - E  Fracos/Moderados
# 3                          95        SE - E  Fracos/Moderados
# 4                          95        SE - E  Fracos/Moderados
# ...                       ...           ...               ...
# 8841                      100       SE - NE  Fracos/Moderados
# 8842                      100       SE - NE  Fracos/Moderados
# 8843                      100       SE - NE  Fracos/Moderados
# 8844                      100       SE - NE  Fracos/Moderados
# 8845                      100       SE - NE  Fracos/Moderados
#
# [8846 rows x 10 columns]

# %%
def tbl_data(x_data):
    #mycursor = mydb.cursor()
    sql = "INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)"
    d, m, a = x_data.split("/")
    val = (d.strip(), m.strip(), a.strip())
    print(val)
    print(sql)
    #mycursor.execute(sql, val)
    #mydb.commit()
    #return mycursor.lastrowid

# %%
def tbl_localizacao(x_local):
    #mycursor = mydb.cursor()
    sql = "INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)"
    cidade, uf = x_local.split('-')
    val = (cidade.strip(), uf.strip(), 'BRASIL')
    print(val)
    print(sql.format(val))
    #mycursor.execute(sql, val)
    #mydb.commit()
    #return mycursor.lastrowid

# %%
def tbl_temperatura(x_temp):
    #mycursor = mydb.cursor()
    sql = "INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)"
    val = (x_temp.strip())
    print(val)
    print(sql.format(val))
    #mycursor.execute(sql, val)
    #mydb.commit()
    #return mycursor.lastrowid

# %%
def tbl_vento(x_vento_dir, x_vento_int):
    #mycursor = mydb.cursor()
    sql = "INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)"
    val = (x_vento_dir.strip(), x_vento_int.strip())
    print(val)
    print(sql.format(val))
    #mycursor.execute(sql, val)
    #mydb.commit()
    #return mycursor.lastrowid

# %%
def inserir_linha(row):
    id_data  = tbl_data(row['Data'])
    id_local = tbl_localizacao(row['Cidade'])
    id_temp  = tbl_temperatura(row['Temperatura_Tendencia'])
    id_vento = tbl_vento(row['Vento_Direcao'], row['Vento_Intensidade'])
    
    Condicao_do_Tempo_Prevista

    
    #mycursor = mydb.cursor()
    sql = "INSERT INTO Tempo (id_data, id_localizacao, id_temperatura, id_vento, "
    sql .=" vento_velocidade_minima, vento_velocidade_maxima, "
    sql .=" temperatura_Minima, temperatura_Maxima, condicao_do_Tempo_Prevista)"
    sql .= " VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s)"
    val = (id_data, id_local, id_temp, id_vento, 
            row['Vento_Velocidade_Minima'].strip(),row['Vento_Velocidade_Maxima'].strip(),
            row['Temperatura_Minima'].strip(), row['Temperatura_Maxima'].strip(),
            row['Condicao_do_Tempo_Prevista'].strip())
    print(val)
    print(sql.format(val))
    #mycursor.execute(sql, val)
    #mydb.commit()
    #return mycursor.lastrowid

# %%
df.apply(lambda x: inserir_linha(x), axis = 1)
# Out:
# ('04', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Abaetetuba', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('SE - E', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('05', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Abaetetuba', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('SE - E', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('06', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Abaetetuba', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('SE - E', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('07', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Abaetetuba', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('SE - E', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('08', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Abaetetuba', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('SE - E', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('09', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Abaetetuba', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('SE - E', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('10', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Abaetetuba', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('SE - NE', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('11', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Abaetetuba', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('E - NE', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('13', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Abaetetuba', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('E - NE', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('14', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Abaetetuba', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('E - NE', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('15', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Abaetetuba', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('E - NE', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('16', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Abaetetuba', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('E - NE', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('17', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Abaetetuba', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('E - NE', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('18', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Abaetetuba', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('E - NE', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('19', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Abaetetuba', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('E - NE', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('20', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Abaetetuba', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('E - NE', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('21', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Abaetetuba', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('E - NE', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('22', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Abaetetuba', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('E - NE', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('23', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Abaetetuba', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('E - NE', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('24', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Abaetetuba', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('E - NE', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('25', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Abaetetuba', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('E - NE', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('26', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Abaetetuba', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Declinio
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('E - NE', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('27', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Abaetetuba', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('E - NE', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('28', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Abaetetuba', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('E - NE', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('29', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Abaetetuba', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('E - NE', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('30', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Abaetetuba', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('E - NE', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('31', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Abaetetuba', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('E - NE', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('04', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Abel Figueiredo', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('E', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('05', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Abel Figueiredo', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('E', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('06', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Abel Figueiredo', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('E', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('07', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Abel Figueiredo', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('E', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('08', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Abel Figueiredo', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('E', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('09', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Abel Figueiredo', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('E', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('10', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Abel Figueiredo', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('NE - SE', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('11', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Abel Figueiredo', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('NE - E', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('13', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Abel Figueiredo', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('NE - E', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('14', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Abel Figueiredo', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('NE - E', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('15', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Abel Figueiredo', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Declinio
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('NE - E', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('16', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Abel Figueiredo', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('NE - E', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('17', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Abel Figueiredo', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('NE - E', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('18', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Abel Figueiredo', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('NE - E', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('19', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Abel Figueiredo', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('NE - E', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('20', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Abel Figueiredo', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('NE - E', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('21', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Abel Figueiredo', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('NE - E', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('22', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Abel Figueiredo', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('NE - E', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('23', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Abel Figueiredo', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('NE - E', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('24', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Abel Figueiredo', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('NE - E', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('25', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Abel Figueiredo', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('NE - E', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('26', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Abel Figueiredo', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Declinio
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('SE - NE', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('27', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Abel Figueiredo', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('SE - NE', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('28', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Abel Figueiredo', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Elevacao
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('SE - NE', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('29', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Abel Figueiredo', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('SE - NE', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('30', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Abel Figueiredo', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('SE - NE', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('31', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Abel Figueiredo', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('SE - NE', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('04', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Acara', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('SE - E', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('05', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Acara', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('SE - E', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('06', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Acara', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('SE - E', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('07', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Acara', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('SE - E', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('08', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Acara', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('SE - E', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('09', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Acara', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('SE - E', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('10', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Acara', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('SE - NE', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('11', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Acara', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('E - NE', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('13', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Acara', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('E - NE', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('14', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Acara', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('E - NE', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('15', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Acara', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('E - NE', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('16', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Acara', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('E - NE', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('17', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Acara', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('E - NE', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('18', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Acara', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('E - NE', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('19', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Acara', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('E - NE', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('20', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Acara', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('E - NE', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('21', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Acara', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('E - NE', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('22', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Acara', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('E - NE', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('23', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Acara', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('E - NE', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('24', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Acara', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('E - NE', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('25', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Acara', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('E - NE', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('26', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Acara', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Declinio
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('E - NE', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('27', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Acara', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('E - NE', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('28', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Acara', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('E - NE', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('29', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Acara', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('E - NE', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('30', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Acara', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('E - NE', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('31', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Acara', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('E - NE', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('04', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Acrelandia', 'AC', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('NW', 'Fracos')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('05', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Acrelandia', 'AC', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('NW - N', 'Fracos')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('06', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Acrelandia', 'AC', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('NW - NE', 'Fracos')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('07', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Acrelandia', 'AC', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Declinio
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('SE - S', 'Fracos')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('08', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Acrelandia', 'AC', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('NW', 'Fracos')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('09', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Acrelandia', 'AC', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('NW - NE', 'Fracos')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('10', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Acrelandia', 'AC', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('NW - NE', 'Fracos')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('11', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Acrelandia', 'AC', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('NW - NE', 'Fracos')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('12', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Acrelandia', 'AC', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('NW - NE', 'Fracos')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('13', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Acrelandia', 'AC', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('NW - NE', 'Fracos')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('14', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Acrelandia', 'AC', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('NE', 'Fracos')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('15', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Acrelandia', 'AC', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('NE', 'Fracos')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('16', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Acrelandia', 'AC', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('NE', 'Fracos')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('17', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Acrelandia', 'AC', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('NE', 'Fracos')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('18', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Acrelandia', 'AC', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('NE', 'Fracos')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('19', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Acrelandia', 'AC', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('NE', 'Fracos')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('20', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Acrelandia', 'AC', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('NE', 'Fracos')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('21', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Acrelandia', 'AC', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('NE', 'Fracos')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('22', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Acrelandia', 'AC', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('NE', 'Fracos')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('23', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Acrelandia', 'AC', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('NE', 'Fracos')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('24', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Acrelandia', 'AC', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('NE', 'Fracos')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('25', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Acrelandia', 'AC', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('W - NW', 'Fracos')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('26', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Acrelandia', 'AC', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('NW - N', 'Fracos')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('27', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Acrelandia', 'AC', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('NW - N', 'Fracos')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('28', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Acrelandia', 'AC', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('NW - N', 'Fracos')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('29', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Acrelandia', 'AC', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('NW - N', 'Fracos')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('30', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Acrelandia', 'AC', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('NW - N', 'Fracos')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('04', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Afua', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('SE - E', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('05', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Afua', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('SE - E', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('06', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Afua', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('SE - E', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('07', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Afua', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('SE - E', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('08', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Afua', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('SE - E', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('09', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Afua', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('SE - E', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('10', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Afua', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Declinio
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('SE - E', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('11', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Afua', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('E - NE', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('13', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Afua', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('E - NE', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('14', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Afua', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('E - NE', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('15', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Afua', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('E - NE', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('16', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Afua', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('E - NE', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('17', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Afua', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('E - NE', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('18', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Afua', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('E - NE', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('19', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Afua', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('E - NE', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('20', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Afua', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('E - NE', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('21', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Afua', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('E - NE', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('22', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Afua', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('E - NE', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('23', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Afua', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('E - NE', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('24', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Afua', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('E - NE', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('25', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Afua', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('E - NE', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('26', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Afua', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Declinio
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('E - NE', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('27', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Afua', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('E - NE', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('28', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Afua', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('E - NE', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('29', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Afua', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('E - NE', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('30', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Afua', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Elevacao
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('E - NE', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('31', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Afua', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('E - NE', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('04', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Agua Azul do Norte', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('NE - SE', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('05', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Agua Azul do Norte', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('NE - SE', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('06', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Agua Azul do Norte', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('NE - SE', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('07', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Agua Azul do Norte', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('NE - SE', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('08', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Agua Azul do Norte', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('NE - SE', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('09', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Agua Azul do Norte', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('NE - SE', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('10', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Agua Azul do Norte', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('NE - SE', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('11', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Agua Azul do Norte', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('SE - NE', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('13', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Agua Azul do Norte', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('SE - NE', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('14', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Agua Azul do Norte', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('SE - NE', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('15', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Agua Azul do Norte', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Declinio
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('E - NE', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('16', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Agua Azul do Norte', 'PA', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('E - NE', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ...
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('NE', 'Fracos')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('13', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Governador Jorge Teixeira', 'RO', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('NE', 'Fracos')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('14', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Governador Jorge Teixeira', 'RO', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('NE', 'Fracos')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('15', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Governador Jorge Teixeira', 'RO', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('NE', 'Fracos')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('16', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Governador Jorge Teixeira', 'RO', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('NE', 'Fracos')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('17', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Governador Jorge Teixeira', 'RO', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('NE', 'Fracos')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('18', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Governador Jorge Teixeira', 'RO', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('NE', 'Fracos')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('19', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Governador Jorge Teixeira', 'RO', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('NE', 'Fracos')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('20', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Governador Jorge Teixeira', 'RO', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('NE', 'Fracos')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('21', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Governador Jorge Teixeira', 'RO', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('NE', 'Fracos')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('22', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Governador Jorge Teixeira', 'RO', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('NE', 'Fracos')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('23', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Governador Jorge Teixeira', 'RO', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('NE', 'Fracos')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('24', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Governador Jorge Teixeira', 'RO', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('NE', 'Fracos')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('25', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Governador Jorge Teixeira', 'RO', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('NW - NE', 'Fracos')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('26', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Governador Jorge Teixeira', 'RO', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('NW - NE', 'Fracos')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('27', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Governador Jorge Teixeira', 'RO', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('NE - N', 'Fracos')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('28', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Governador Jorge Teixeira', 'RO', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('NW - NE', 'Fracos')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('29', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Governador Jorge Teixeira', 'RO', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('NW - NE', 'Fracos')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('30', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Governador Jorge Teixeira', 'RO', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('NW - N', 'Fracos')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('04', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Guajara', 'AM', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('NW - NE', 'Fracos')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('05', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Guajara', 'AM', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('NE - N', 'Fracos')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('06', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Guajara', 'AM', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('N - SE', 'Fracos')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('07', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Guajara', 'AM', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('NE - W', 'Fracos')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('08', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Guajara', 'AM', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('SW - W', 'Fracos')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('09', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Guajara', 'AM', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('NW - SW', 'Fracos')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('10', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Guajara', 'AM', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('NW - SW', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('11', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Guajara', 'AM', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('NW - W', 'Fracos')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('12', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Guajara', 'AM', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('N - NE', 'Fracos')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('13', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Guajara', 'AM', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('NE - E', 'Fracos')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('14', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Guajara', 'AM', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('SE - S', 'Fracos')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('15', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Guajara', 'AM', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('SW - SE', 'Fracos')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('16', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Guajara', 'AM', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('SW - SE', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('18', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Guajara', 'AM', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('N - NE', 'Fracos')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('19', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Guajara', 'AM', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('NE - N', 'Fracos')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('20', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Guajara', 'AM', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('NW - NE', 'Fracos')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('21', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Guajara', 'AM', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('NW - NE', 'Fracos')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('22', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Guajara', 'AM', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Declinio
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('SW - SE', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('23', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Guajara', 'AM', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Declinio
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('S - SE', 'Fracos/Moderados')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('26', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Guajara', 'AM', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('N - NW', 'Fracos')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('27', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Guajara', 'AM', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('NE - N', 'Fracos')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('28', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Guajara', 'AM', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('NE - SW', 'Fracos')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('29', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Guajara', 'AM', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('NW - N', 'Fracos')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('30', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ('Guajara', 'AM', 'BRASIL')
# INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)
# Estavel
# INSERT INTO temperatura (temperatura_tendencia) VALUES (%s)
# ('N - NE', 'Fracos')
# INSERT INTO Vento (temperatura_tendencia) VALUES (%s, %s)
# ('04', '10', '2022')
# INSERT INTO data (dia, mes, ano) VALUES (%s, %s, %s)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-76-a2f07f553d4a> in <module>
# ----> 1 df.apply(lambda x: inserir_linha(x), axis = 1)
#
# c:\users\ricar\appdata\local\programs\python\python37\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, raw, result_type, args, **kwds)
#    6876             kwds=kwds,
#    6877         )
# -> 6878         return op.get_result()
#    6879
#    6880     def applymap(self, func) -> "DataFrame":
#
# c:\users\ricar\appdata\local\programs\python\python37\lib\site-packages\pandas\core\apply.py in get_result(self)
#     184             return self.apply_raw()
#     185
# --> 186         return self.apply_standard()
#     187
#     188     def apply_empty_result(self):
#
# c:\users\ricar\appdata\local\programs\python\python37\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#     294             try:
#     295                 result = libreduction.compute_reduction(
# --> 296                     values, self.f, axis=self.axis, dummy=dummy, labels=labels
#     297                 )
#     298             except ValueError as err:
#
# pandas\_libs\reduction.pyx in pandas._libs.reduction.compute_reduction()
#
# pandas\_libs\reduction.pyx in pandas._libs.reduction.Reducer.get_result()
#
# <ipython-input-76-a2f07f553d4a> in <lambda>(x)
# ----> 1 df.apply(lambda x: inserir_linha(x), axis = 1)
#
# <ipython-input-75-c3702184ff4e> in inserir_linha(row)
#       1 def inserir_linha(row):
#       2     id_data  = tbl_data(row['Data'])
# ----> 3     id_local = tbl_localizacao(row['Cidade'])
#       4     id_temp  = tbl_temperatura(row['Temperatura_Tendencia'])
#       5     id_vento = tbl_vento(row['Vento_Direcao'], row['Vento_Intensidade'])
#
# <ipython-input-70-18379074728c> in tbl_localizacao(x_local)
#       2     #mycursor = mydb.cursor()
#       3     sql = "INSERT INTO localizacao (cidade, estado, pais) VALUES (%s, %s, %s)"
# ----> 4     cidade, uf = x_local.split('-')
#       5     val = (cidade.strip(), uf.strip(), 'BRASIL')
#       6     print(val)
#
# ValueError: too many values to unpack (expected 2)
